# %%
import os
from datetime import date, datetime, timedelta
from marshmallow import Schema, fields
import numpy as np
import pandas as pd
from pprint import pprint
from dateutil.relativedelta import relativedelta
import json

# %%
dirname = "data/2024/2"
dfNum = pd.read_table(f"{dirname}/num.txt",delimiter="\t", low_memory=False)
dfPre = pd.read_table(f"{dirname}/pre.txt",delimiter="\t", low_memory=False)
dfSub = pd.read_table(f"{dirname}/sub.txt",delimiter="\t", low_memory=False)
dfTag = pd.read_table(f"{dirname}/tag.txt",delimiter="\t", low_memory=False)
dfSym = pd.read_table(f"{dirname}/ticker.txt", delimiter="\t", header=None, names=['symbol','cik'], low_memory=False)

# %%
class FinancialElementImportDto:
    label = ""          #Tag.doc
    concept = ""        #Num.tag
    info = ""           #Pre.plabel
    unit = ""           #Num.uom
    value = 0.0         #Num.value

class FinancialsDataDto:
    bs = []  #FinancialElementImportDto[] mapping key from Pre.stmt
    cf = []  #FinancialElementImportDto[] mapping key from Pre.stmt
    ic = []  #FinancialElementImportDto[] mapping key from Pre.stmt
    

class SymbolFinancialsDto:
    startDate = date.today()   #Sub.period 
    endDate = date.today()     #Sub.period + Sub.fp
    year = 0                   #Sub.fy
    quarter = ""               #Sub.fp
    symbol = ""                #Sub.cik -> Sym.cik -> Sym.symbol
    name = ""                  #Sub.name
    country = ""               #Sub.countryma
    city = ""                  #Sub.cityma
    data = FinancialsDataDto()
    
class FinancialElementImportSchema(Schema):
    label = fields.String()
    concept = fields.String()
    info = fields.String()
    unit = fields.String()
    value = fields.Int()
    
class FinancialsDataSchema(Schema):
    bs = fields.List(fields.Nested(FinancialElementImportSchema()))
    cf = fields.List(fields.Nested(FinancialElementImportSchema()))
    ic = fields.List(fields.Nested(FinancialElementImportSchema()))
    
class SymbolFinancialsSchema(Schema):
    startDate = fields.DateTime()
    endDate = fields.DateTime()
    year = fields.Int()
    quarter = fields.String()
    symbol = fields.String()
    name = fields.String()
    country = fields.String()
    city = fields.String()
    data = fields.Nested(FinancialsDataSchema)

# %%
def npInt_to_str(var):
    return str(list(np.reshape(np.asarray(var), (1, np.size(var)))[0]))[1:-1]

def formatDateNpNum(var):
    dateStr = npInt_to_str(var)
    return dateStr[0:4]+"-"+dateStr[4:6]+"-"+dateStr[6:8]

fileStartTime = datetime.now()
for subId in range(len(dfSub)):
    startTime = datetime.now()
    submitted = dfSub.iloc[subId]
    sfDto = SymbolFinancialsDto()
    sfDto.data = FinancialsDataDto()
    sfDto.data.bs = []
    sfDto.data.cf = []
    sfDto.data.ic = []
    try:
        periodStartDate = date.fromisoformat(formatDateNpNum(submitted["period"]))
    except ValueError:
        print("File exportFiles/"+dirname+"/"+submitted["adsh"]+".json has Period: "+str(submitted["period"]))
        continue       
    sfDto.startDate = periodStartDate
    sfDto.endDate = date.today() #default value
    if submitted["fy"] == np.nan or np.isnan(submitted["fy"]):
        sfDto.year = 0
    else: 
        sfDto.year = submitted["fy"].astype(int)        
    sfDto.quarter = str(submitted["fp"]).strip().upper()
    
    if sfDto.quarter == "FY" or sfDto.quarter == "CY":
        sfDto.endDate = periodStartDate + relativedelta(months=+12, days=-1)
    elif sfDto.quarter == "H1" or sfDto.quarter == "H2":
        sfDto.endDate = periodStartDate + relativedelta(months=+6, days=-1)
    elif sfDto.quarter == "T1" or sfDto.quarter == "T2" or sfDto.quarter == "T3":
        sfDto.endDate = periodStartDate + relativedelta(months=+4, days=-1)
    elif sfDto.quarter == "Q1" or sfDto.quarter == "Q2" or sfDto.quarter == "Q3" or sfDto.quarter == "Q4":
        sfDto.endDate = periodStartDate + relativedelta(months=+3, days=-1)
    else:
        continue
        
    #symStr = dfSym[dfSym["cik"]==submitted.cik].symbol.str.upper().astype("string")
    #print(symStr)
    val = dfSym[dfSym["cik"]==submitted["cik"]]
    if len(val) > 0:
        sfDto.symbol = val["symbol"].to_string(index = False).split("\n")[0].split("\\n")[0].strip().split(" ")[0].strip().upper()
        if len(sfDto.symbol) > 19 or len(sfDto.symbol) < 1:
            print("File exportFiles/"+dirname+"/"+submitted["adsh"]+".json has Symbol "+sfDto.symbol)
    else:
        print("File exportFiles/"+dirname+"/"+submitted["adsh"]+".json has Symbol "+val["symbol"].to_string(index = False))
        continue
        
    sfDto.name = submitted["name"]
    sfDto.country = submitted["countryma"]
    sfDto.city = submitted["cityma"]

    sdDto = FinancialsDataDto()
    #print(filteredDfPre)
    dfNum['value'] = pd.to_numeric(dfNum['value'], errors='coerce')
    dfNum = dfNum.dropna(subset=['value'])
    dfNum['value'] = dfNum['value'].astype(int)
    #filteredDfNum = dfNum[dfNum['adsh'] == submitted['adsh']]       
    filteredDfNum = dfNum.loc[dfNum['adsh'].values == submitted['adsh']]
    filteredDfNum.reset_index()

    for myId in range(len(filteredDfNum)): 
        #print(myId)
        #print(filteredDfNum.iloc[myId])
        myNum = filteredDfNum.iloc[myId]
        myDto = FinancialElementImportDto()
        myTag = dfTag[dfTag["tag"] == myNum['tag']]
        myDto.label = myTag["doc"].to_string(index = False)
        myDto.concept = myNum["tag"]
        #myPre = dfPre[(dfPre['adsh'] == submitted["adsh"]) & (dfPre['tag'] == myNum['tag'])]
        myPre = dfPre.loc[np.where((dfPre['adsh'].values == submitted["adsh"]) & (dfPre['tag'].values == myNum['tag']))]
        myDto.info = myPre["plabel"].to_string(index = False).replace('"',"'")
        myDto.unit = myNum["uom"]
        #print(myNum["value"])        
        myDto.value = myNum["value"]
        #print(myDto.__dict__)
        #FinancialElementImportSchema().dump(myDto)
        if myPre['stmt'].to_string(index = False).strip() == 'BS':
            sfDto.data.bs.append(myDto)
        elif myPre['stmt'].to_string(index = False).strip() == 'CF':
            sfDto.data.cf.append(myDto)
        elif myPre['stmt'].to_string(index = False).strip() == 'IS':
            sfDto.data.ic.append(myDto)

    #print(len(filteredDfNum))
    #print(submitted)
    #print(sfDto.__dict__)    
    #json.dumps(sfDto.__dict__)    
    marshmellowStart = datetime.now()
    result = SymbolFinancialsSchema().dump(sfDto)
    result = str(json.dumps(result))
    #result = result.replace('"','öäü').replace("'", '"').replace("öäü","'").replace(", ",",")
    result = result.replace('\\r', '').replace('\\n', ' ')
    
    print("FilterDfNum size: "+str(len(filteredDfNum))+" Dtos size: "+str((len(sfDto.data.bs)+len(sfDto.data.cf)+len(sfDto.data.ic)))+" Bs: "+str(len(sfDto.data.bs))+" Cf: "+str(len(sfDto.data.cf))+" Ic: "+str(len(sfDto.data.ic))+" Json size: "+str(int(len(str(result)) / 1024))+"kb.")
    
    #print("Json size "+str(int(len(str(result)) / 1024))+"kb. Time: "+str((datetime.now() - marshmellowStart) / timedelta(milliseconds=1))+"ms.")
    
    #print(result)
    #pprint(result)    
    isExist = os.path.exists("exportFiles/"+dirname)
    if not isExist:
        os.makedirs("exportFiles/"+dirname)
    json_file = open("exportFiles/"+dirname+"/"+submitted["adsh"]+".json","w")
    json_file.write(result)
    json_file.close()
    endTime = datetime.now()
    print("file "+str(subId+1)+" of "+str(len(dfSub)+1)+" exportFiles/"+dirname+"/"+submitted["adsh"]+".json stored in "+str((endTime - startTime) / timedelta(milliseconds=1))+"ms.")
    
fileEndTime = datetime.now()
print("Time "+str((fileEndTime - fileStartTime) / timedelta(seconds=1))+"sec for "+str(len(dfSub)+1)+" files.")
# Out:
# FilterDfNum size: 291 Dtos size: 221 Bs: 87 Cf: 46 Ic: 88 Json size: 61kb.
# file 1 of 7676 exportFiles/data/2024/2/0000002178-24-000054.json stored in 5353.026ms.
# FilterDfNum size: 247 Dtos size: 183 Bs: 70 Cf: 55 Ic: 58 Json size: 51kb.
# file 2 of 7676 exportFiles/data/2024/2/0000002488-24-000056.json stored in 4477.103ms.
# FilterDfNum size: 786 Dtos size: 451 Bs: 136 Cf: 87 Ic: 228 Json size: 125kb.
# file 3 of 7676 exportFiles/data/2024/2/0000002969-24-000026.json stored in 13763.548ms.
# FilterDfNum size: 204 Dtos size: 139 Bs: 73 Cf: 42 Ic: 24 Json size: 38kb.
# file 4 of 7676 exportFiles/data/2024/2/0000003499-24-000015.json stored in 4062.469ms.
# FilterDfNum size: 427 Dtos size: 315 Bs: 100 Cf: 76 Ic: 139 Json size: 91kb.
# file 5 of 7676 exportFiles/data/2024/2/0000003545-24-000066.json stored in 7667.548ms.
# FilterDfNum size: 426 Dtos size: 260 Bs: 148 Cf: 62 Ic: 50 Json size: 92kb.
# file 6 of 7676 exportFiles/data/2024/2/0000003570-24-000055.json stored in 7575.063ms.
# FilterDfNum size: 378 Dtos size: 228 Bs: 74 Cf: 66 Ic: 88 Json size: 66kb.
# file 7 of 7676 exportFiles/data/2024/2/0000004127-24-000019.json stored in 6810.063ms.
# FilterDfNum size: 331 Dtos size: 242 Bs: 62 Cf: 59 Ic: 121 Json size: 68kb.
# file 8 of 7676 exportFiles/data/2024/2/0000004281-24-000014.json stored in 6034.784ms.
# FilterDfNum size: 3267 Dtos size: 2216 Bs: 1527 Cf: 473 Ic: 216 Json size: 572kb.
# file 9 of 7676 exportFiles/data/2024/2/0000004904-24-000046.json stored in 56261.166ms.
# FilterDfNum size: 424 Dtos size: 321 Bs: 155 Cf: 56 Ic: 110 Json size: 87kb.
# file 10 of 7676 exportFiles/data/2024/2/0000004962-24-000031.json stored in 7694.03ms.
# FilterDfNum size: 1165 Dtos size: 893 Bs: 761 Cf: 70 Ic: 62 Json size: 248kb.
# file 11 of 7676 exportFiles/data/2024/2/0000004977-24-000086.json stored in 20356.624ms.
# FilterDfNum size: 1154 Dtos size: 811 Bs: 556 Cf: 113 Ic: 142 Json size: 226kb.
# file 12 of 7676 exportFiles/data/2024/2/0000005272-24-000051.json stored in 20348.959ms.
# FilterDfNum size: 662 Dtos size: 558 Bs: 348 Cf: 54 Ic: 156 Json size: 147kb.
# file 13 of 7676 exportFiles/data/2024/2/0000005513-24-000095.json stored in 11835.582ms.
# FilterDfNum size: 549 Dtos size: 8 Bs: 0 Cf: 0 Ic: 8 Json size: 2kb.
# file 14 of 7676 exportFiles/data/2024/2/0000006201-24-000032.json stored in 9886.007ms.
# FilterDfNum size: 370 Dtos size: 244 Bs: 70 Cf: 46 Ic: 128 Json size: 71kb.
# file 15 of 7676 exportFiles/data/2024/2/0000006281-24-000132.json stored in 6782.739ms.
# FilterDfNum size: 463 Dtos size: 313 Bs: 113 Cf: 122 Ic: 78 Json size: 90kb.
# file 16 of 7676 exportFiles/data/2024/2/0000006845-24-000088.json stored in 8428.559ms.
# FilterDfNum size: 420 Dtos size: 256 Bs: 60 Cf: 64 Ic: 132 Json size: 73kb.
# file 17 of 7676 exportFiles/data/2024/2/0000006951-24-000022.json stored in 7677.575ms.
# FilterDfNum size: 384 Dtos size: 324 Bs: 136 Cf: 76 Ic: 112 Json size: 95kb.
# file 18 of 7676 exportFiles/data/2024/2/0000006955-24-000042.json stored in 7029.688ms.
# FilterDfNum size: 389 Dtos size: 270 Bs: 82 Cf: 65 Ic: 123 Json size: 75kb.
# file 19 of 7676 exportFiles/data/2024/2/0000007084-24-000017.json stored in 7078.775ms.
# FilterDfNum size: 394 Dtos size: 291 Bs: 109 Cf: 40 Ic: 142 Json size: 82kb.
# file 20 of 7676 exportFiles/data/2024/2/0000007332-24-000017.json stored in 7071.337ms.
# FilterDfNum size: 734 Dtos size: 557 Bs: 323 Cf: 114 Ic: 120 Json size: 149kb.
# file 21 of 7676 exportFiles/data/2024/2/0000007789-24-000043.json stored in 12811.738ms.
# FilterDfNum size: 286 Dtos size: 187 Bs: 65 Cf: 60 Ic: 62 Json size: 73kb.
# file 22 of 7676 exportFiles/data/2024/2/0000008063-24-000029.json stored in 5289.714ms.
# FilterDfNum size: 474 Dtos size: 409 Bs: 158 Cf: 71 Ic: 180 Json size: 121kb.
# file 23 of 7676 exportFiles/data/2024/2/0000008670-24-000014.json stored in 8417.202ms.
# FilterDfNum size: 238 Dtos size: 212 Bs: 98 Cf: 52 Ic: 62 Json size: 64kb.
# file 24 of 7676 exportFiles/data/2024/2/0000008818-24-000009.json stored in 4405.222ms.
# FilterDfNum size: 347 Dtos size: 197 Bs: 59 Cf: 46 Ic: 92 Json size: 56kb.
# file 25 of 7676 exportFiles/data/2024/2/0000008858-24-000020.json stored in 6358.175ms.
# FilterDfNum size: 589 Dtos size: 431 Bs: 117 Cf: 104 Ic: 210 Json size: 130kb.
# file 26 of 7676 exportFiles/data/2024/2/0000008947-24-000044.json stored in 11022.245ms.
# FilterDfNum size: 337 Dtos size: 297 Bs: 132 Cf: 62 Ic: 103 Json size: 87kb.
# file 27 of 7676 exportFiles/data/2024/2/0000009984-24-000063.json stored in 6236.21ms.
# FilterDfNum size: 393 Dtos size: 218 Bs: 89 Cf: 48 Ic: 81 Json size: 61kb.
# file 28 of 7676 exportFiles/data/2024/2/0000010048-24-000010.json stored in 7039.843ms.
# FilterDfNum size: 442 Dtos size: 396 Bs: 136 Cf: 42 Ic: 218 Json size: 109kb.
# file 29 of 7676 exportFiles/data/2024/2/0000010795-24-000039.json stored in 7910.289ms.
# FilterDfNum size: 430 Dtos size: 326 Bs: 166 Cf: 64 Ic: 96 Json size: 81kb.
# file 30 of 7676 exportFiles/data/2024/2/0000011544-24-000012.json stored in 7633.685ms.
# FilterDfNum size: 307 Dtos size: 198 Bs: 98 Cf: 42 Ic: 58 Json size: 58kb.
# file 31 of 7676 exportFiles/data/2024/2/0000012208-24-000039.json stored in 5565.08ms.
# FilterDfNum size: 346 Dtos size: 246 Bs: 106 Cf: 78 Ic: 62 Json size: 69kb.
# file 32 of 7676 exportFiles/data/2024/2/0000012927-24-000025.json stored in 6270.099ms.
# FilterDfNum size: 282 Dtos size: 252 Bs: 100 Cf: 60 Ic: 92 Json size: 71kb.
# file 33 of 7676 exportFiles/data/2024/2/0000014272-24-000096.json stored in 5254.474ms.
# FilterDfNum size: 398 Dtos size: 293 Bs: 93 Cf: 101 Ic: 99 Json size: 83kb.
# file 34 of 7676 exportFiles/data/2024/2/0000014693-24-000086.json stored in 7498.91ms.
# FilterDfNum size: 572 Dtos size: 404 Bs: 102 Cf: 115 Ic: 187 Json size: 114kb.
# file 35 of 7676 exportFiles/data/2024/2/0000014707-24-000012.json stored in 10449.245ms.
# FilterDfNum size: 403 Dtos size: 290 Bs: 115 Cf: 59 Ic: 116 Json size: 81kb.
# file 36 of 7676 exportFiles/data/2024/2/0000014707-24-000024.json stored in 7314.412ms.
# FilterDfNum size: 258 Dtos size: 179 Bs: 82 Cf: 47 Ic: 50 Json size: 48kb.
# file 37 of 7676 exportFiles/data/2024/2/0000014846-24-000027.json stored in 4726.985ms.
# FilterDfNum size: 443 Dtos size: 319 Bs: 184 Cf: 58 Ic: 77 Json size: 89kb.
# file 38 of 7676 exportFiles/data/2024/2/0000014930-24-000103.json stored in 11665.991ms.
# FilterDfNum size: 367 Dtos size: 246 Bs: 130 Cf: 68 Ic: 48 Json size: 71kb.
# file 39 of 7676 exportFiles/data/2024/2/0000015615-24-000045.json stored in 8056.95ms.
# FilterDfNum size: 531 Dtos size: 339 Bs: 88 Cf: 59 Ic: 192 Json size: 132kb.
# file 40 of 7676 exportFiles/data/2024/2/0000016058-24-000070.json stored in 12203.792ms.
# FilterDfNum size: 490 Dtos size: 287 Bs: 89 Cf: 62 Ic: 136 Json size: 81kb.
# file 41 of 7676 exportFiles/data/2024/2/0000016732-24-000082.json stored in 9010.271ms.
# FilterDfNum size: 273 Dtos size: 170 Bs: 76 Cf: 41 Ic: 53 Json size: 49kb.
# file 42 of 7676 exportFiles/data/2024/2/0000016875-24-000016.json stored in 5137.132ms.
# FilterDfNum size: 583 Dtos size: 435 Bs: 140 Cf: 145 Ic: 150 Json size: 123kb.
# file 43 of 7676 exportFiles/data/2024/2/0000016918-24-000054.json stored in 10374.813ms.
# FilterDfNum size: 4373 Dtos size: 437 Bs: 94 Cf: 126 Ic: 217 Json size: 113kb.
# file 44 of 7676 exportFiles/data/2024/2/0000017313-24-000022.json stored in 77086.989ms.
# FilterDfNum size: 427 Dtos size: 255 Bs: 77 Cf: 82 Ic: 96 Json size: 73kb.
# file 45 of 7676 exportFiles/data/2024/2/0000017843-24-000006.json stored in 8389.756ms.
# FilterDfNum size: 506 Dtos size: 393 Bs: 112 Cf: 87 Ic: 194 Json size: 112kb.
# file 46 of 7676 exportFiles/data/2024/2/0000018230-24-000020.json stored in 480526.025ms.
# FilterDfNum size: 715 Dtos size: 572 Bs: 394 Cf: 68 Ic: 110 Json size: 165kb.
# file 47 of 7676 exportFiles/data/2024/2/0000018349-24-000086.json stored in 16962.144ms.
# FilterDfNum size: 356 Dtos size: 276 Bs: 86 Cf: 68 Ic: 122 Json size: 75kb.
# file 48 of 7676 exportFiles/data/2024/2/0000018926-24-000054.json stored in 6537.209ms.
# FilterDfNum size: 1000 Dtos size: 705 Bs: 488 Cf: 78 Ic: 139 Json size: 190kb.
# file 49 of 7676 exportFiles/data/2024/2/0000019617-24-000326.json stored in 18110.128ms.
# FilterDfNum size: 412 Dtos size: 351 Bs: 105 Cf: 72 Ic: 174 Json size: 100kb.
# file 50 of 7676 exportFiles/data/2024/2/0000020212-24-000071.json stored in 7473.361ms.
# FilterDfNum size: 469 Dtos size: 390 Bs: 230 Cf: 66 Ic: 94 Json size: 104kb.
# file 51 of 7676 exportFiles/data/2024/2/0000020286-24-000030.json stored in 8281.762ms.
# FilterDfNum size: 343 Dtos size: 316 Bs: 170 Cf: 44 Ic: 102 Json size: 96kb.
# file 52 of 7676 exportFiles/data/2024/2/0000021076-24-000016.json stored in 6584.369ms.
# FilterDfNum size: 567 Dtos size: 461 Bs: 241 Cf: 66 Ic: 154 Json size: 117kb.
# file 53 of 7676 exportFiles/data/2024/2/0000021175-24-000039.json stored in 10278.699ms.
# FilterDfNum size: 301 Dtos size: 271 Bs: 107 Cf: 60 Ic: 104 Json size: 77kb.
# file 54 of 7676 exportFiles/data/2024/2/0000021344-24-000017.json stored in 5567.324ms.
# FilterDfNum size: 285 Dtos size: 186 Bs: 70 Cf: 60 Ic: 56 Json size: 52kb.
# file 55 of 7676 exportFiles/data/2024/2/0000021665-24-000015.json stored in 5124.403ms.
# FilterDfNum size: 547 Dtos size: 438 Bs: 242 Cf: 68 Ic: 128 Json size: 120kb.
# file 56 of 7676 exportFiles/data/2024/2/0000022356-24-000035.json stored in 9580.433ms.
# FilterDfNum size: 571 Dtos size: 387 Bs: 101 Cf: 60 Ic: 226 Json size: 112kb.
# file 57 of 7676 exportFiles/data/2024/2/0000022444-24-000089.json stored in 10055.496ms.
# FilterDfNum size: 389 Dtos size: 277 Bs: 120 Cf: 80 Ic: 77 Json size: 75kb.
# file 58 of 7676 exportFiles/data/2024/2/0000022701-24-000002.json stored in 7426.607ms.
# FilterDfNum size: 320 Dtos size: 225 Bs: 108 Cf: 57 Ic: 60 Json size: 64kb.
# file 59 of 7676 exportFiles/data/2024/2/0000022701-24-000004.json stored in 6055.067ms.
# FilterDfNum size: 765 Dtos size: 551 Bs: 119 Cf: 180 Ic: 252 Json size: 147kb.
# file 60 of 7676 exportFiles/data/2024/2/0000023197-24-000080.json stored in 15453.306ms.
# FilterDfNum size: 758 Dtos size: 601 Bs: 381 Cf: 56 Ic: 164 Json size: 149kb.
# file 61 of 7676 exportFiles/data/2024/2/0000024090-24-000088.json stored in 13915.904ms.
# FilterDfNum size: 326 Dtos size: 220 Bs: 116 Cf: 46 Ic: 58 Json size: 63kb.
# file 62 of 7676 exportFiles/data/2024/2/0000024545-24-000012.json stored in 6033.8ms.
# FilterDfNum size: 341 Dtos size: 232 Bs: 82 Cf: 42 Ic: 108 Json size: 63kb.
# file 63 of 7676 exportFiles/data/2024/2/0000025232-24-000024.json stored in 6896.635ms.
# FilterDfNum size: 459 Dtos size: 342 Bs: 105 Cf: 61 Ic: 176 Json size: 98kb.
# file 64 of 7676 exportFiles/data/2024/2/0000026172-24-000023.json stored in 8266.934ms.
# FilterDfNum size: 263 Dtos size: 196 Bs: 101 Cf: 46 Ic: 49 Json size: 57kb.
# file 65 of 7676 exportFiles/data/2024/2/0000026324-24-000012.json stored in 4918.838ms.
# FilterDfNum size: 308 Dtos size: 206 Bs: 114 Cf: 42 Ic: 50 Json size: 58kb.
# file 66 of 7676 exportFiles/data/2024/2/0000027419-24-000129.json stored in 6330.185ms.
# FilterDfNum size: 308 Dtos size: 245 Bs: 91 Cf: 34 Ic: 120 Json size: 68kb.
# file 67 of 7676 exportFiles/data/2024/2/0000027904-24-000006.json stored in 7409.792ms.
# FilterDfNum size: 322 Dtos size: 254 Bs: 117 Cf: 54 Ic: 83 Json size: 69kb.
# file 68 of 7676 exportFiles/data/2024/2/0000027996-24-000120.json stored in 6149.399ms.
# FilterDfNum size: 527 Dtos size: 447 Bs: 234 Cf: 64 Ic: 149 Json size: 119kb.
# file 69 of 7676 exportFiles/data/2024/2/0000028412-24-000263.json stored in 9416.353ms.
# FilterDfNum size: 379 Dtos size: 330 Bs: 162 Cf: 88 Ic: 80 Json size: 92kb.
# file 70 of 7676 exportFiles/data/2024/2/0000028823-24-000041.json stored in 7107.361ms.
# FilterDfNum size: 222 Dtos size: 171 Bs: 85 Cf: 44 Ic: 42 Json size: 47kb.
# file 71 of 7676 exportFiles/data/2024/2/0000028917-24-000022.json stored in 4726.956ms.
# FilterDfNum size: 263 Dtos size: 184 Bs: 82 Cf: 56 Ic: 46 Json size: 52kb.
# file 72 of 7676 exportFiles/data/2024/2/0000029332-24-000036.json stored in 73878.42ms.
# FilterDfNum size: 430 Dtos size: 271 Bs: 95 Cf: 50 Ic: 126 Json size: 80kb.
# file 73 of 7676 exportFiles/data/2024/2/0000029644-24-000067.json stored in 13838.437ms.
# FilterDfNum size: 278 Dtos size: 183 Bs: 67 Cf: 50 Ic: 66 Json size: 54kb.
# file 74 of 7676 exportFiles/data/2024/2/0000029905-24-000020.json stored in 5589.24ms.
# File exportFiles/data/2024/2/0000029915-24-000006.json has Symbol Series([], )
# FilterDfNum size: 300 Dtos size: 211 Bs: 92 Cf: 51 Ic: 68 Json size: 58kb.
# file 76 of 7676 exportFiles/data/2024/2/0000029989-24-000014.json stored in 5703.646ms.
# FilterDfNum size: 362 Dtos size: 252 Bs: 88 Cf: 70 Ic: 94 Json size: 68kb.
# file 77 of 7676 exportFiles/data/2024/2/0000030625-24-000041.json stored in 6726.172ms.
# FilterDfNum size: 386 Dtos size: 242 Bs: 88 Cf: 52 Ic: 102 Json size: 67kb.
# file 78 of 7676 exportFiles/data/2024/2/0000030697-24-000009.json stored in 7056.171ms.
# FilterDfNum size: 348 Dtos size: 245 Bs: 69 Cf: 68 Ic: 108 Json size: 72kb.
# file 79 of 7676 exportFiles/data/2024/2/0000031791-24-000014.json stored in 6610.816ms.
# FilterDfNum size: 564 Dtos size: 385 Bs: 84 Cf: 114 Ic: 187 Json size: 114kb.
# file 80 of 7676 exportFiles/data/2024/2/0000032604-24-000024.json stored in 10215.127ms.
# FilterDfNum size: 342 Dtos size: 228 Bs: 118 Cf: 44 Ic: 66 Json size: 66kb.
# file 81 of 7676 exportFiles/data/2024/2/0000033185-24-000032.json stored in 6318.633ms.
# FilterDfNum size: 290 Dtos size: 198 Bs: 82 Cf: 62 Ic: 54 Json size: 54kb.
# file 82 of 7676 exportFiles/data/2024/2/0000033213-24-000021.json stored in 5342.903ms.
# FilterDfNum size: 350 Dtos size: 256 Bs: 97 Cf: 52 Ic: 107 Json size: 72kb.
# file 83 of 7676 exportFiles/data/2024/2/0000034067-24-000075.json stored in 6328.111ms.
# FilterDfNum size: 320 Dtos size: 204 Bs: 62 Cf: 48 Ic: 94 Json size: 56kb.
# file 84 of 7676 exportFiles/data/2024/2/0000034088-24-000029.json stored in 5827.146ms.
# FilterDfNum size: 426 Dtos size: 252 Bs: 82 Cf: 52 Ic: 118 Json size: 73kb.
# file 85 of 7676 exportFiles/data/2024/2/0000034563-24-000046.json stored in 7595.965ms.
# FilterDfNum size: 651 Dtos size: 552 Bs: 396 Cf: 80 Ic: 76 Json size: 144kb.
# file 86 of 7676 exportFiles/data/2024/2/0000034782-24-000054.json stored in 11458.101ms.
# FilterDfNum size: 608 Dtos size: 375 Bs: 176 Cf: 117 Ic: 82 Json size: 98kb.
# file 87 of 7676 exportFiles/data/2024/2/0000034903-24-000046.json stored in 10698.558ms.
# FilterDfNum size: 1107 Dtos size: 679 Bs: 321 Cf: 74 Ic: 284 Json size: 188kb.
# file 88 of 7676 exportFiles/data/2024/2/0000035527-24-000166.json stored in 22884.825ms.
# FilterDfNum size: 791 Dtos size: 469 Bs: 294 Cf: 57 Ic: 118 Json size: 126kb.
# file 89 of 7676 exportFiles/data/2024/2/0000036104-24-000037.json stored in 14362.112ms.
# FilterDfNum size: 999 Dtos size: 847 Bs: 599 Cf: 72 Ic: 176 Json size: 229kb.
# file 90 of 7676 exportFiles/data/2024/2/0000036966-24-000060.json stored in 17347.981ms.
# FilterDfNum size: 406 Dtos size: 241 Bs: 88 Cf: 75 Ic: 78 Json size: 67kb.
# file 91 of 7676 exportFiles/data/2024/2/0000037785-24-000066.json stored in 7311.54ms.
# FilterDfNum size: 753 Dtos size: 639 Bs: 451 Cf: 60 Ic: 128 Json size: 184kb.
# file 92 of 7676 exportFiles/data/2024/2/0000037808-24-000011.json stored in 13391.424ms.
# FilterDfNum size: 457 Dtos size: 313 Bs: 113 Cf: 66 Ic: 134 Json size: 90kb.
# file 93 of 7676 exportFiles/data/2024/2/0000037996-24-000075.json stored in 8163.175ms.
# File exportFiles/data/2024/2/0000038009-24-000034.json has Symbol Series([], )
# File exportFiles/data/2024/2/0000038723-24-000047.json has Symbol Series([], )
# File exportFiles/data/2024/2/0000038723-24-000084.json has Symbol Series([], )
# FilterDfNum size: 304 Dtos size: 268 Bs: 142 Cf: 60 Ic: 66 Json size: 76kb.
# file 97 of 7676 exportFiles/data/2024/2/0000038725-24-000078.json stored in 5746.646ms.
# FilterDfNum size: 765 Dtos size: 422 Bs: 116 Cf: 94 Ic: 212 Json size: 120kb.
# file 98 of 7676 exportFiles/data/2024/2/0000038777-24-000069.json stored in 13337.192ms.
# FilterDfNum size: 654 Dtos size: 536 Bs: 358 Cf: 66 Ic: 112 Json size: 144kb.
# file 99 of 7676 exportFiles/data/2024/2/0000039263-24-000039.json stored in 11584.514ms.
# FilterDfNum size: 643 Dtos size: 512 Bs: 370 Cf: 72 Ic: 70 Json size: 144kb.
# file 100 of 7676 exportFiles/data/2024/2/0000039311-24-000056.json stored in 11318.254ms.
# FilterDfNum size: 303 Dtos size: 217 Bs: 87 Cf: 54 Ic: 76 Json size: 59kb.
# file 101 of 7676 exportFiles/data/2024/2/0000039911-24-000128.json stored in 5559.886ms.
# FilterDfNum size: 335 Dtos size: 264 Bs: 78 Cf: 48 Ic: 138 Json size: 72kb.
# file 102 of 7676 exportFiles/data/2024/2/0000040211-24-000039.json stored in 5979.414ms.
# FilterDfNum size: 372 Dtos size: 310 Bs: 86 Cf: 44 Ic: 180 Json size: 88kb.
# file 103 of 7676 exportFiles/data/2024/2/0000040533-24-000014.json stored in 6653.068ms.
# FilterDfNum size: 463 Dtos size: 334 Bs: 139 Cf: 87 Ic: 108 Json size: 95kb.
# file 104 of 7676 exportFiles/data/2024/2/0000040545-24-000113.json stored in 8268.676ms.
# FilterDfNum size: 858 Dtos size: 489 Bs: 287 Cf: 80 Ic: 122 Json size: 143kb.
# file 105 of 7676 exportFiles/data/2024/2/0000040729-24-000012.json stored in 15356.753ms.
# FilterDfNum size: 273 Dtos size: 165 Bs: 72 Cf: 40 Ic: 53 Json size: 47kb.
# file 106 of 7676 exportFiles/data/2024/2/0000040987-24-000068.json stored in 5428.182ms.
# FilterDfNum size: 373 Dtos size: 269 Bs: 58 Cf: 70 Ic: 141 Json size: 81kb.
# file 107 of 7676 exportFiles/data/2024/2/0000041719-24-000018.json stored in 7015.171ms.
# FilterDfNum size: 228 Dtos size: 160 Bs: 70 Cf: 46 Ic: 44 Json size: 45kb.
# file 108 of 7676 exportFiles/data/2024/2/0000042888-24-000014.json stored in 4347.561ms.
# FilterDfNum size: 703 Dtos size: 393 Bs: 128 Cf: 83 Ic: 182 Json size: 116kb.
# file 109 of 7676 exportFiles/data/2024/2/0000043920-24-000030.json stored in 13000.03ms.
# FilterDfNum size: 245 Dtos size: 198 Bs: 96 Cf: 42 Ic: 60 Json size: 57kb.
# file 110 of 7676 exportFiles/data/2024/2/0000045012-24-000015.json stored in 4550.781ms.
# FilterDfNum size: 537 Dtos size: 410 Bs: 113 Cf: 82 Ic: 215 Json size: 136kb.
# file 111 of 7676 exportFiles/data/2024/2/0000045876-24-000026.json stored in 9440.245ms.
# FilterDfNum size: 319 Dtos size: 256 Bs: 82 Cf: 74 Ic: 100 Json size: 77kb.
# file 112 of 7676 exportFiles/data/2024/2/0000045919-24-000014.json stored in 5686.354ms.
# FilterDfNum size: 271 Dtos size: 210 Bs: 78 Cf: 48 Ic: 84 Json size: 65kb.
# file 113 of 7676 exportFiles/data/2024/2/0000045919-24-000026.json stored in 4927.764ms.
# FilterDfNum size: 369 Dtos size: 258 Bs: 123 Cf: 52 Ic: 83 Json size: 74kb.
# file 114 of 7676 exportFiles/data/2024/2/0000046080-24-000085.json stored in 6504.547ms.
# FilterDfNum size: 486 Dtos size: 320 Bs: 100 Cf: 94 Ic: 126 Json size: 89kb.
# file 115 of 7676 exportFiles/data/2024/2/0000046250-24-000013.json stored in 8550.259ms.
# FilterDfNum size: 472 Dtos size: 231 Bs: 78 Cf: 73 Ic: 80 Json size: 65kb.
# file 116 of 7676 exportFiles/data/2024/2/0000046619-24-000039.json stored in 8746.902ms.
# FilterDfNum size: 538 Dtos size: 357 Bs: 104 Cf: 63 Ic: 190 Json size: 98kb.
# file 117 of 7676 exportFiles/data/2024/2/0000046765-24-000030.json stored in 9588.067ms.
# FilterDfNum size: 308 Dtos size: 183 Bs: 71 Cf: 66 Ic: 46 Json size: 52kb.
# file 118 of 7676 exportFiles/data/2024/2/0000047111-24-000023.json stored in 5674.652ms.
# FilterDfNum size: 501 Dtos size: 297 Bs: 56 Cf: 57 Ic: 184 Json size: 79kb.
# file 119 of 7676 exportFiles/data/2024/2/0000047217-24-000041.json stored in 8912.173ms.
# FilterDfNum size: 281 Dtos size: 208 Bs: 82 Cf: 52 Ic: 74 Json size: 59kb.
# file 120 of 7676 exportFiles/data/2024/2/0000048287-24-000097.json stored in 5254.649ms.
# FilterDfNum size: 469 Dtos size: 273 Bs: 115 Cf: 62 Ic: 96 Json size: 79kb.
# file 121 of 7676 exportFiles/data/2024/2/0000048465-24-000032.json stored in 8401.26ms.
# FilterDfNum size: 524 Dtos size: 407 Bs: 138 Cf: 69 Ic: 200 Json size: 108kb.
# file 122 of 7676 exportFiles/data/2024/2/0000049071-24-000023.json stored in 9397.053ms.
# FilterDfNum size: 970 Dtos size: 756 Bs: 556 Cf: 80 Ic: 120 Json size: 209kb.
# file 123 of 7676 exportFiles/data/2024/2/0000049196-24-000047.json stored in 21598.005ms.
# FilterDfNum size: 320 Dtos size: 180 Bs: 69 Cf: 73 Ic: 38 Json size: 48kb.
# file 124 of 7676 exportFiles/data/2024/2/0000049600-24-000065.json stored in 11597.71ms.
# FilterDfNum size: 236 Dtos size: 160 Bs: 66 Cf: 69 Ic: 25 Json size: 44kb.
# file 125 of 7676 exportFiles/data/2024/2/0000049826-24-000020.json stored in 6607.404ms.
# FilterDfNum size: 366 Dtos size: 264 Bs: 74 Cf: 54 Ic: 136 Json size: 68kb.
# file 126 of 7676 exportFiles/data/2024/2/0000049938-24-000021.json stored in 7269.163ms.
# FilterDfNum size: 319 Dtos size: 225 Bs: 80 Cf: 37 Ic: 108 Json size: 82kb.
# file 127 of 7676 exportFiles/data/2024/2/0000050493-24-000008.json stored in 6581.328ms.
# FilterDfNum size: 509 Dtos size: 331 Bs: 61 Cf: 56 Ic: 214 Json size: 96kb.
# file 128 of 7676 exportFiles/data/2024/2/0000050725-24-000071.json stored in 10902.05ms.
# FilterDfNum size: 304 Dtos size: 221 Bs: 64 Cf: 65 Ic: 92 Json size: 62kb.
# file 129 of 7676 exportFiles/data/2024/2/0000050863-24-000076.json stored in 7368.684ms.
# FilterDfNum size: 407 Dtos size: 281 Bs: 139 Cf: 48 Ic: 94 Json size: 87kb.
# file 130 of 7676 exportFiles/data/2024/2/0000051143-24-000025.json stored in 8023.374ms.
# FilterDfNum size: 351 Dtos size: 255 Bs: 108 Cf: 61 Ic: 86 Json size: 74kb.
# file 131 of 7676 exportFiles/data/2024/2/0000051253-24-000016.json stored in 6943.025ms.
# FilterDfNum size: 279 Dtos size: 260 Bs: 98 Cf: 50 Ic: 112 Json size: 73kb.
# file 132 of 7676 exportFiles/data/2024/2/0000051434-24-000034.json stored in 5525.039ms.
# FilterDfNum size: 419 Dtos size: 280 Bs: 96 Cf: 66 Ic: 118 Json size: 79kb.
# file 133 of 7676 exportFiles/data/2024/2/0000051644-24-000021.json stored in 8204.629ms.
# FilterDfNum size: 660 Dtos size: 48 Bs: 35 Cf: 7 Ic: 6 Json size: 15kb.
# file 134 of 7676 exportFiles/data/2024/2/0000052827-24-000150.json stored in 14413.972ms.
# FilterDfNum size: 585 Dtos size: 335 Bs: 109 Cf: 74 Ic: 152 Json size: 96kb.
# file 135 of 7676 exportFiles/data/2024/2/0000052988-24-000032.json stored in 12540.377ms.
# FilterDfNum size: 348 Dtos size: 258 Bs: 86 Cf: 62 Ic: 110 Json size: 73kb.
# file 136 of 7676 exportFiles/data/2024/2/0000055135-24-000018.json stored in 7090.793ms.
# FilterDfNum size: 379 Dtos size: 293 Bs: 150 Cf: 55 Ic: 88 Json size: 87kb.
# file 137 of 7676 exportFiles/data/2024/2/0000055242-24-000026.json stored in 7883.688ms.
# FilterDfNum size: 302 Dtos size: 226 Bs: 94 Cf: 62 Ic: 70 Json size: 63kb.
# file 138 of 7676 exportFiles/data/2024/2/0000055529-24-000021.json stored in 10229.622ms.
# FilterDfNum size: 300 Dtos size: 173 Bs: 62 Cf: 50 Ic: 61 Json size: 46kb.
# file 139 of 7676 exportFiles/data/2024/2/0000055785-24-000054.json stored in 5988.86ms.
# FilterDfNum size: 299 Dtos size: 225 Bs: 87 Cf: 57 Ic: 81 Json size: 64kb.
# file 140 of 7676 exportFiles/data/2024/2/0000056701-24-000014.json stored in 5745.314ms.
# FilterDfNum size: 445 Dtos size: 270 Bs: 92 Cf: 58 Ic: 120 Json size: 86kb.
# file 141 of 7676 exportFiles/data/2024/2/0000056978-24-000064.json stored in 8247.062ms.
# FilterDfNum size: 467 Dtos size: 333 Bs: 110 Cf: 94 Ic: 129 Json size: 109kb.
# file 142 of 7676 exportFiles/data/2024/2/0000057131-24-000028.json stored in 9586.622ms.
# FilterDfNum size: 398 Dtos size: 218 Bs: 72 Cf: 42 Ic: 104 Json size: 61kb.
# file 143 of 7676 exportFiles/data/2024/2/0000057515-24-000012.json stored in 7527.147ms.
# FilterDfNum size: 307 Dtos size: 224 Bs: 90 Cf: 56 Ic: 78 Json size: 64kb.
# file 144 of 7676 exportFiles/data/2024/2/0000058492-24-000338.json stored in 5804.377ms.
# FilterDfNum size: 337 Dtos size: 218 Bs: 105 Cf: 77 Ic: 36 Json size: 75kb.
# file 145 of 7676 exportFiles/data/2024/2/0000059440-24-000011.json stored in 6199.871ms.
# FilterDfNum size: 433 Dtos size: 327 Bs: 79 Cf: 46 Ic: 202 Json size: 85kb.
# file 146 of 7676 exportFiles/data/2024/2/0000059478-24-000118.json stored in 8041.336ms.
# FilterDfNum size: 244 Dtos size: 154 Bs: 52 Cf: 48 Ic: 54 Json size: 44kb.
# file 147 of 7676 exportFiles/data/2024/2/0000059527-24-000015.json stored in 4658.223ms.
# FilterDfNum size: 923 Dtos size: 820 Bs: 658 Cf: 62 Ic: 100 Json size: 200kb.
# file 148 of 7676 exportFiles/data/2024/2/0000059558-24-000024.json stored in 16399.46ms.
# FilterDfNum size: 489 Dtos size: 329 Bs: 143 Cf: 58 Ic: 128 Json size: 91kb.
# file 149 of 7676 exportFiles/data/2024/2/0000060086-24-000086.json stored in 8931.245ms.
# FilterDfNum size: 319 Dtos size: 228 Bs: 108 Cf: 54 Ic: 66 Json size: 61kb.
# file 150 of 7676 exportFiles/data/2024/2/0000060667-24-000085.json stored in 5922.685ms.
# FilterDfNum size: 214 Dtos size: 172 Bs: 64 Cf: 38 Ic: 70 Json size: 48kb.
# file 151 of 7676 exportFiles/data/2024/2/0000061398-24-000022.json stored in 4206.71ms.
# FilterDfNum size: 339 Dtos size: 304 Bs: 114 Cf: 78 Ic: 112 Json size: 83kb.
# file 152 of 7676 exportFiles/data/2024/2/0000062234-24-000028.json stored in 6768.817ms.
# FilterDfNum size: 337 Dtos size: 245 Bs: 101 Cf: 74 Ic: 70 Json size: 68kb.
# file 153 of 7676 exportFiles/data/2024/2/0000062709-24-000037.json stored in 6344.152ms.
# FilterDfNum size: 257 Dtos size: 171 Bs: 73 Cf: 36 Ic: 62 Json size: 49kb.
# file 154 of 7676 exportFiles/data/2024/2/0000062996-24-000012.json stored in 4823.349ms.
# FilterDfNum size: 685 Dtos size: 323 Bs: 76 Cf: 77 Ic: 170 Json size: 93kb.
# file 155 of 7676 exportFiles/data/2024/2/0000063296-24-000045.json stored in 17675.223ms.
# FilterDfNum size: 453 Dtos size: 275 Bs: 58 Cf: 50 Ic: 167 Json size: 79kb.
# file 156 of 7676 exportFiles/data/2024/2/0000063754-24-000057.json stored in 9513.438ms.
# FilterDfNum size: 285 Dtos size: 179 Bs: 84 Cf: 43 Ic: 52 Json size: 60kb.
# file 157 of 7676 exportFiles/data/2024/2/0000063908-24-000092.json stored in 5899.433ms.
# FilterDfNum size: 500 Dtos size: 340 Bs: 80 Cf: 56 Ic: 204 Json size: 96kb.
# file 158 of 7676 exportFiles/data/2024/2/0000064040-24-000125.json stored in 9921.291ms.
# FilterDfNum size: 448 Dtos size: 300 Bs: 160 Cf: 64 Ic: 76 Json size: 77kb.
# file 159 of 7676 exportFiles/data/2024/2/0000064803-24-000016.json stored in 11348.551ms.
# FilterDfNum size: 321 Dtos size: 298 Bs: 176 Cf: 60 Ic: 62 Json size: 75kb.
# file 160 of 7676 exportFiles/data/2024/2/0000064996-24-000019.json stored in 8662.701ms.
# FilterDfNum size: 2111 Dtos size: 1661 Bs: 762 Cf: 459 Ic: 440 Json size: 458kb.
# file 161 of 7676 exportFiles/data/2024/2/0000065984-24-000049.json stored in 40069.991ms.
# FilterDfNum size: 635 Dtos size: 348 Bs: 99 Cf: 55 Ic: 194 Json size: 99kb.
# file 162 of 7676 exportFiles/data/2024/2/0000066382-24-000014.json stored in 11798.407ms.
# FilterDfNum size: 281 Dtos size: 217 Bs: 89 Cf: 60 Ic: 68 Json size: 62kb.
# file 163 of 7676 exportFiles/data/2024/2/0000066570-24-000022.json stored in 5397.665ms.
# FilterDfNum size: 285 Dtos size: 252 Bs: 134 Cf: 54 Ic: 64 Json size: 72kb.
# file 164 of 7676 exportFiles/data/2024/2/0000066740-24-000053.json stored in 5356.325ms.
# FilterDfNum size: 326 Dtos size: 246 Bs: 117 Cf: 69 Ic: 60 Json size: 65kb.
# file 165 of 7676 exportFiles/data/2024/2/0000066756-24-000050.json stored in 6028.838ms.
# FilterDfNum size: 271 Dtos size: 190 Bs: 94 Cf: 56 Ic: 40 Json size: 65kb.
# file 166 of 7676 exportFiles/data/2024/2/0000067215-24-000029.json stored in 5547.169ms.
# FilterDfNum size: 545 Dtos size: 440 Bs: 236 Cf: 100 Ic: 104 Json size: 115kb.
# file 167 of 7676 exportFiles/data/2024/2/0000067716-24-000055.json stored in 10253.688ms.
# FilterDfNum size: 592 Dtos size: 378 Bs: 76 Cf: 76 Ic: 226 Json size: 99kb.
# file 168 of 7676 exportFiles/data/2024/2/0000067887-24-000029.json stored in 10929.277ms.
# FilterDfNum size: 321 Dtos size: 236 Bs: 90 Cf: 54 Ic: 92 Json size: 66kb.
# file 169 of 7676 exportFiles/data/2024/2/0000068505-24-000016.json stored in 6093.431ms.
# FilterDfNum size: 171 Dtos size: 149 Bs: 59 Cf: 48 Ic: 42 Json size: 40kb.
# file 170 of 7676 exportFiles/data/2024/2/0000068622-24-000007.json stored in 4498.844ms.
# FilterDfNum size: 465 Dtos size: 359 Bs: 152 Cf: 58 Ic: 149 Json size: 98kb.
# file 171 of 7676 exportFiles/data/2024/2/0000070145-24-000013.json stored in 13717.592ms.
# FilterDfNum size: 337 Dtos size: 294 Bs: 148 Cf: 66 Ic: 80 Json size: 85kb.
# file 172 of 7676 exportFiles/data/2024/2/0000070318-24-000032.json stored in 7166.676ms.
# FilterDfNum size: 948 Dtos size: 691 Bs: 305 Cf: 98 Ic: 288 Json size: 184kb.
# file 173 of 7676 exportFiles/data/2024/2/0000070502-24-000031.json stored in 17302.343ms.
# FilterDfNum size: 1291 Dtos size: 1104 Bs: 878 Cf: 72 Ic: 154 Json size: 312kb.
# file 174 of 7676 exportFiles/data/2024/2/0000070858-24-000156.json stored in 23073.762ms.
# FilterDfNum size: 473 Dtos size: 365 Bs: 136 Cf: 54 Ic: 175 Json size: 106kb.
# file 175 of 7676 exportFiles/data/2024/2/0000070866-24-000025.json stored in 8905.475ms.
# FilterDfNum size: 324 Dtos size: 208 Bs: 90 Cf: 46 Ic: 72 Json size: 60kb.
# file 176 of 7676 exportFiles/data/2024/2/0000071691-24-000105.json stored in 6024.57ms.
# FilterDfNum size: 231 Dtos size: 176 Bs: 67 Cf: 55 Ic: 54 Json size: 50kb.
# file 177 of 7676 exportFiles/data/2024/2/0000071829-24-000036.json stored in 4341.687ms.
# FilterDfNum size: 373 Dtos size: 245 Bs: 84 Cf: 45 Ic: 116 Json size: 70kb.
# file 178 of 7676 exportFiles/data/2024/2/0000072331-24-000075.json stored in 6895.767ms.
# FilterDfNum size: 223 Dtos size: 174 Bs: 80 Cf: 58 Ic: 36 Json size: 48kb.
# file 179 of 7676 exportFiles/data/2024/2/0000072333-24-000080.json stored in 4317.356ms.
# FilterDfNum size: 1036 Dtos size: 60 Bs: 20 Cf: 14 Ic: 26 Json size: 16kb.
# file 180 of 7676 exportFiles/data/2024/2/0000072741-24-000010.json stored in 18242.046ms.
# FilterDfNum size: 318 Dtos size: 245 Bs: 111 Cf: 74 Ic: 60 Json size: 68kb.
# file 181 of 7676 exportFiles/data/2024/2/0000072903-24-000096.json stored in 6268.357ms.
# File exportFiles/data/2024/2/0000072909-24-000007.json has Symbol Series([], )
# FilterDfNum size: 1198 Dtos size: 653 Bs: 315 Cf: 78 Ic: 260 Json size: 176kb.
# file 183 of 7676 exportFiles/data/2024/2/0000072971-24-000129.json stored in 21384.449ms.
# FilterDfNum size: 856 Dtos size: 730 Bs: 542 Cf: 74 Ic: 114 Json size: 204kb.
# file 184 of 7676 exportFiles/data/2024/2/0000073124-24-000159.json stored in 15227.879ms.
# FilterDfNum size: 264 Dtos size: 191 Bs: 55 Cf: 58 Ic: 78 Json size: 53kb.
# file 185 of 7676 exportFiles/data/2024/2/0000073756-24-000081.json stored in 5007.326ms.
# FilterDfNum size: 568 Dtos size: 300 Bs: 94 Cf: 66 Ic: 140 Json size: 84kb.
# file 186 of 7676 exportFiles/data/2024/2/0000074046-24-000043.json stored in 10218.809ms.
# FilterDfNum size: 361 Dtos size: 246 Bs: 107 Cf: 61 Ic: 78 Json size: 67kb.
# file 187 of 7676 exportFiles/data/2024/2/0000074208-24-000039.json stored in 6586.3ms.
# FilterDfNum size: 405 Dtos size: 313 Bs: 191 Cf: 60 Ic: 62 Json size: 82kb.
# file 188 of 7676 exportFiles/data/2024/2/0000074260-24-000084.json stored in 7246.919ms.
# FilterDfNum size: 399 Dtos size: 309 Bs: 116 Cf: 70 Ic: 123 Json size: 84kb.
# file 189 of 7676 exportFiles/data/2024/2/0000074303-24-000105.json stored in 7217.643ms.
# FilterDfNum size: 383 Dtos size: 308 Bs: 108 Cf: 104 Ic: 96 Json size: 90kb.
# file 190 of 7676 exportFiles/data/2024/2/0000075288-24-000003.json stored in 7243.557ms.
# FilterDfNum size: 252 Dtos size: 204 Bs: 97 Cf: 49 Ic: 58 Json size: 59kb.
# file 191 of 7676 exportFiles/data/2024/2/0000075288-24-000009.json stored in 4883.583ms.
# FilterDfNum size: 320 Dtos size: 223 Bs: 47 Cf: 56 Ic: 120 Json size: 62kb.
# file 192 of 7676 exportFiles/data/2024/2/0000076282-24-000033.json stored in 6460.562ms.
# FilterDfNum size: 414 Dtos size: 354 Bs: 140 Cf: 88 Ic: 126 Json size: 103kb.
# file 193 of 7676 exportFiles/data/2024/2/0000076334-24-000020.json stored in 12300.595ms.
# FilterDfNum size: 270 Dtos size: 221 Bs: 76 Cf: 55 Ic: 90 Json size: 64kb.
# file 194 of 7676 exportFiles/data/2024/2/0000076605-24-000109.json stored in 6048.579ms.
# FilterDfNum size: 264 Dtos size: 200 Bs: 64 Cf: 66 Ic: 70 Json size: 57kb.
# file 195 of 7676 exportFiles/data/2024/2/0000077360-24-000020.json stored in 5479.691ms.
# FilterDfNum size: 336 Dtos size: 233 Bs: 88 Cf: 87 Ic: 58 Json size: 63kb.
# file 196 of 7676 exportFiles/data/2024/2/0000077476-24-000017.json stored in 7575.217ms.
# FilterDfNum size: 445 Dtos size: 367 Bs: 139 Cf: 52 Ic: 176 Json size: 107kb.
# file 197 of 7676 exportFiles/data/2024/2/0000077543-24-000106.json stored in 9978.563ms.
# FilterDfNum size: 459 Dtos size: 325 Bs: 104 Cf: 61 Ic: 160 Json size: 89kb.
# file 198 of 7676 exportFiles/data/2024/2/0000078003-24-000107.json stored in 8871.497ms.
# FilterDfNum size: 638 Dtos size: 468 Bs: 145 Cf: 150 Ic: 173 Json size: 128kb.
# file 199 of 7676 exportFiles/data/2024/2/0000078239-24-000013.json stored in 13890.55ms.
# FilterDfNum size: 394 Dtos size: 281 Bs: 133 Cf: 56 Ic: 92 Json size: 77kb.
# file 200 of 7676 exportFiles/data/2024/2/0000078239-24-000042.json stored in 8215.252ms.
# FilterDfNum size: 312 Dtos size: 258 Bs: 128 Cf: 64 Ic: 66 Json size: 74kb.
# file 201 of 7676 exportFiles/data/2024/2/0000078814-24-000026.json stored in 6526.718ms.
# FilterDfNum size: 416 Dtos size: 282 Bs: 92 Cf: 90 Ic: 100 Json size: 79kb.
# file 202 of 7676 exportFiles/data/2024/2/0000078890-24-000172.json stored in 8275.054ms.
# FilterDfNum size: 307 Dtos size: 206 Bs: 90 Cf: 60 Ic: 56 Json size: 58kb.
# file 203 of 7676 exportFiles/data/2024/2/0000079879-24-000107.json stored in 6161.021ms.
# FilterDfNum size: 362 Dtos size: 242 Bs: 86 Cf: 51 Ic: 105 Json size: 69kb.
# file 204 of 7676 exportFiles/data/2024/2/0000080420-24-000030.json stored in 7033.322ms.
# FilterDfNum size: 439 Dtos size: 228 Bs: 76 Cf: 52 Ic: 100 Json size: 71kb.
# file 205 of 7676 exportFiles/data/2024/2/0000080424-24-000051.json stored in 12062.655ms.
# FilterDfNum size: 662 Dtos size: 580 Bs: 411 Cf: 70 Ic: 99 Json size: 164kb.
# file 206 of 7676 exportFiles/data/2024/2/0000080661-24-000018.json stored in 15758.125ms.
# File exportFiles/data/2024/2/0000081018-24-000010.json has Symbol Series([], )
# File exportFiles/data/2024/2/0000081061-24-000024.json has Symbol Series([], )
# FilterDfNum size: 284 Dtos size: 218 Bs: 110 Cf: 48 Ic: 60 Json size: 63kb.
# file 209 of 7676 exportFiles/data/2024/2/0000081362-24-000058.json stored in 5748.292ms.
# FilterDfNum size: 375 Dtos size: 276 Bs: 104 Cf: 66 Ic: 106 Json size: 79kb.
# file 210 of 7676 exportFiles/data/2024/2/0000082811-24-000088.json stored in 7597.898ms.
# File exportFiles/data/2024/2/0000083246-24-000009.json has Symbol Series([], )
# FilterDfNum size: 326 Dtos size: 269 Bs: 169 Cf: 56 Ic: 44 Json size: 68kb.
# file 212 of 7676 exportFiles/data/2024/2/0000083350-24-000013.json stored in 6465.651ms.
# FilterDfNum size: 340 Dtos size: 278 Bs: 94 Cf: 52 Ic: 132 Json size: 78kb.
# file 213 of 7676 exportFiles/data/2024/2/0000084748-24-000028.json stored in 6471.484ms.
# FilterDfNum size: 264 Dtos size: 198 Bs: 88 Cf: 62 Ic: 48 Json size: 57kb.
# file 214 of 7676 exportFiles/data/2024/2/0000084839-24-000070.json stored in 5054.539ms.
# FilterDfNum size: 373 Dtos size: 321 Bs: 174 Cf: 49 Ic: 98 Json size: 87kb.
# file 215 of 7676 exportFiles/data/2024/2/0000085535-24-000010.json stored in 6966.371ms.
# FilterDfNum size: 350 Dtos size: 233 Bs: 69 Cf: 60 Ic: 104 Json size: 74kb.
# file 216 of 7676 exportFiles/data/2024/2/0000085961-24-000078.json stored in 6620.149ms.
# FilterDfNum size: 497 Dtos size: 371 Bs: 189 Cf: 66 Ic: 116 Json size: 99kb.
# file 217 of 7676 exportFiles/data/2024/2/0000086312-24-000032.json stored in 9183.079ms.
# FilterDfNum size: 358 Dtos size: 299 Bs: 133 Cf: 52 Ic: 114 Json size: 86kb.
# file 218 of 7676 exportFiles/data/2024/2/0000088121-24-000060.json stored in 6672.011ms.
# FilterDfNum size: 345 Dtos size: 256 Bs: 84 Cf: 65 Ic: 107 Json size: 71kb.
# file 219 of 7676 exportFiles/data/2024/2/0000088205-24-000039.json stored in 6382.345ms.
# FilterDfNum size: 303 Dtos size: 208 Bs: 80 Cf: 64 Ic: 64 Json size: 60kb.
# file 220 of 7676 exportFiles/data/2024/2/0000088941-24-000065.json stored in 5534.437ms.
# FilterDfNum size: 295 Dtos size: 238 Bs: 90 Cf: 70 Ic: 78 Json size: 67kb.
# file 221 of 7676 exportFiles/data/2024/2/0000089089-24-000093.json stored in 5458.158ms.
# FilterDfNum size: 410 Dtos size: 294 Bs: 99 Cf: 62 Ic: 133 Json size: 84kb.
# file 222 of 7676 exportFiles/data/2024/2/0000089439-24-000025.json stored in 7776.863ms.
# FilterDfNum size: 321 Dtos size: 237 Bs: 111 Cf: 60 Ic: 66 Json size: 86kb.
# file 223 of 7676 exportFiles/data/2024/2/0000089800-24-000087.json stored in 6419.326ms.
# FilterDfNum size: 356 Dtos size: 244 Bs: 80 Cf: 72 Ic: 92 Json size: 68kb.
# file 224 of 7676 exportFiles/data/2024/2/0000090168-24-000014.json stored in 6878.281ms.
# FilterDfNum size: 243 Dtos size: 149 Bs: 68 Cf: 41 Ic: 40 Json size: 42kb.
# file 225 of 7676 exportFiles/data/2024/2/0000091142-24-000132.json stored in 4571.118ms.
# FilterDfNum size: 556 Dtos size: 432 Bs: 182 Cf: 132 Ic: 118 Json size: 122kb.
# file 226 of 7676 exportFiles/data/2024/2/0000091419-24-000054.json stored in 10015.455ms.
# FilterDfNum size: 474 Dtos size: 367 Bs: 131 Cf: 64 Ic: 172 Json size: 99kb.
# file 227 of 7676 exportFiles/data/2024/2/0000091440-24-000029.json stored in 8562.014ms.
# FilterDfNum size: 1013 Dtos size: 854 Bs: 606 Cf: 92 Ic: 156 Json size: 242kb.
# file 228 of 7676 exportFiles/data/2024/2/0000091576-24-000066.json stored in 17945.384ms.
# FilterDfNum size: 397 Dtos size: 267 Bs: 77 Cf: 67 Ic: 123 Json size: 76kb.
# file 229 of 7676 exportFiles/data/2024/2/0000091767-24-000029.json stored in 7291.24ms.
# FilterDfNum size: 1822 Dtos size: 34 Bs: 12 Cf: 14 Ic: 8 Json size: 8kb.
# file 230 of 7676 exportFiles/data/2024/2/0000092122-24-000042.json stored in 39969.793ms.
# FilterDfNum size: 659 Dtos size: 517 Bs: 295 Cf: 62 Ic: 160 Json size: 142kb.
# file 231 of 7676 exportFiles/data/2024/2/0000092230-24-000025.json stored in 12101.205ms.
# FilterDfNum size: 243 Dtos size: 178 Bs: 68 Cf: 54 Ic: 56 Json size: 48kb.
# file 233 of 7676 exportFiles/data/2024/2/0000092380-24-000055.json stored in 4395.618ms.
# File exportFiles/data/2024/2/0000092521-24-000009.json has Symbol Series([], )
# FilterDfNum size: 485 Dtos size: 295 Bs: 134 Cf: 50 Ic: 111 Json size: 85kb.
# file 235 of 7676 exportFiles/data/2024/2/0000093410-24-000021.json stored in 8917.063ms.
# FilterDfNum size: 298 Dtos size: 192 Bs: 82 Cf: 47 Ic: 63 Json size: 54kb.
# file 236 of 7676 exportFiles/data/2024/2/0000093556-24-000091.json stored in 5503.753ms.
# FilterDfNum size: 406 Dtos size: 255 Bs: 79 Cf: 56 Ic: 120 Json size: 71kb.
# file 237 of 7676 exportFiles/data/2024/2/0000093676-24-000010.json stored in 7460.579ms.
# FilterDfNum size: 952 Dtos size: 774 Bs: 513 Cf: 81 Ic: 180 Json size: 217kb.
# file 238 of 7676 exportFiles/data/2024/2/0000093751-24-000587.json stored in 17287.553ms.
# FilterDfNum size: 356 Dtos size: 266 Bs: 120 Cf: 70 Ic: 76 Json size: 73kb.
# file 239 of 7676 exportFiles/data/2024/2/0000094344-24-000009.json stored in 6662.501ms.
# FilterDfNum size: 278 Dtos size: 194 Bs: 68 Cf: 48 Ic: 78 Json size: 55kb.
# file 240 of 7676 exportFiles/data/2024/2/0000094845-24-000026.json stored in 5257.212ms.
# FilterDfNum size: 433 Dtos size: 286 Bs: 69 Cf: 51 Ic: 166 Json size: 82kb.
# file 241 of 7676 exportFiles/data/2024/2/0000094845-24-000045.json stored in 8054.752ms.
# FilterDfNum size: 451 Dtos size: 357 Bs: 106 Cf: 90 Ic: 161 Json size: 101kb.
# file 242 of 7676 exportFiles/data/2024/2/0000095953-24-000018.json stored in 8075.723ms.
# FilterDfNum size: 285 Dtos size: 219 Bs: 84 Cf: 71 Ic: 64 Json size: 62kb.
# file 243 of 7676 exportFiles/data/2024/2/0000095953-24-000028.json stored in 5309.425ms.
# FilterDfNum size: 683 Dtos size: 491 Bs: 80 Cf: 75 Ic: 336 Json size: 137kb.
# file 244 of 7676 exportFiles/data/2024/2/0000096021-24-000043.json stored in 275486.045ms.
# FilterDfNum size: 729 Dtos size: 567 Bs: 357 Cf: 104 Ic: 106 Json size: 159kb.
# file 245 of 7676 exportFiles/data/2024/2/0000096223-24-000015.json stored in 13145.908ms.
# FilterDfNum size: 315 Dtos size: 182 Bs: 80 Cf: 50 Ic: 52 Json size: 53kb.
# file 246 of 7676 exportFiles/data/2024/2/0000096869-24-000008.json stored in 6076.745ms.
# FilterDfNum size: 346 Dtos size: 220 Bs: 66 Cf: 62 Ic: 92 Json size: 64kb.
# file 247 of 7676 exportFiles/data/2024/2/0000096943-24-000072.json stored in 6477.448ms.
# FilterDfNum size: 316 Dtos size: 195 Bs: 75 Cf: 64 Ic: 56 Json size: 55kb.
# file 248 of 7676 exportFiles/data/2024/2/0000097134-24-000016.json stored in 6540.593ms.
# FilterDfNum size: 327 Dtos size: 260 Bs: 86 Cf: 42 Ic: 132 Json size: 75kb.
# file 249 of 7676 exportFiles/data/2024/2/0000097216-24-000099.json stored in 6408.713ms.
# FilterDfNum size: 283 Dtos size: 251 Bs: 132 Cf: 55 Ic: 64 Json size: 71kb.
# file 250 of 7676 exportFiles/data/2024/2/0000097476-24-000021.json stored in 5547.0ms.
# FilterDfNum size: 350 Dtos size: 209 Bs: 74 Cf: 48 Ic: 87 Json size: 59kb.
# file 251 of 7676 exportFiles/data/2024/2/0000097745-24-000023.json stored in 6725.501ms.
# FilterDfNum size: 335 Dtos size: 299 Bs: 153 Cf: 74 Ic: 72 Json size: 86kb.
# file 252 of 7676 exportFiles/data/2024/2/0000098362-24-000053.json stored in 6279.331ms.
# File exportFiles/data/2024/2/0000099250-24-000006.json has Symbol Series([], )
# FilterDfNum size: 414 Dtos size: 293 Bs: 126 Cf: 69 Ic: 98 Json size: 82kb.
# file 254 of 7676 exportFiles/data/2024/2/0000099780-24-000055.json stored in 7696.131ms.
# File exportFiles/data/2024/2/0000100122-24-000005.json has Symbol Series([], )
# FilterDfNum size: 566 Dtos size: 366 Bs: 58 Cf: 48 Ic: 260 Json size: 98kb.
# file 256 of 7676 exportFiles/data/2024/2/0000100493-24-000069.json stored in 10303.585ms.
# FilterDfNum size: 503 Dtos size: 10 Bs: 4 Cf: 2 Ic: 4 Json size: 2kb.
# file 257 of 7676 exportFiles/data/2024/2/0000100517-24-000079.json stored in 9269.148ms.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 70
#      68 myNum = filteredDfNum.iloc[myId]
#      69 myDto = FinancialElementImportDto()
# ---> 70 myTag = dfTag[dfTag["tag"] == myNum['tag']]
#      71 myDto.label = myTag["doc"].to_string(index = False)
#      72 myDto.concept = myNum["tag"]
#
# File /opt/anaconda3/envs/damg7245/lib/python3.12/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File /opt/anaconda3/envs/damg7245/lib/python3.12/site-packages/pandas/core/arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File /opt/anaconda3/envs/damg7245/lib/python3.12/site-packages/pandas/core/series.py:5803, in Series._cmp_method(self, other, op)
#    5800 lvalues = self._values
#    5801 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 5803 res_values = ops.comparison_op(lvalues, rvalues, op)
#    5805 return self._construct_result(res_values, name=res_name)
#
# File /opt/anaconda3/envs/damg7245/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:346, in comparison_op(left, right, op)
#     343     return invalid_comparison(lvalues, rvalues, op)
#     345 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 346     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     348 else:
#     349     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File /opt/anaconda3/envs/damg7245/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:131, in comp_method_OBJECT_ARRAY(op, x, y)
#     129     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     130 else:
# --> 131     result = libops.scalar_compare(x.ravel(), y, op)
#     132 return result.reshape(x.shape)
#
# KeyboardInterrupt:
